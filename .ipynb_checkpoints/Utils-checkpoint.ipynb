# %%
import numpy as np
import cv2
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
p="C:/Users/Anuj_Chauhan/Desktop/IMG/center_2018_07_13_22_05_36_342.jpg"

# %%
#plt.imshow?
#cv2.flip?

# %%
test=cv2.imread(p)
plt.imshow(test,aspect='equal')
plt.show()
test1=cv2.flip(test,1)
plt.imshow(test1,aspect='equal')
plt.show()
test2=cv2.flip(test,2)
plt.imshow(test2,aspect='equal')
plt.show()
test3=cv2.flip(test,3)
plt.imshow(test3,aspect='equal')
plt.show()

# %%
imgh,imgw,imgc=66,200,3 #image height weidth and channels

# %%
inputshape=(imgh,imgw,imgc)

# %%
def read_image(path):
    img=cv2.imread(path)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    return np.array(img)

# %%
def resize_image(img):
    new_img=cv2.resize(img,(imgw,imgh))
    return new_img

# %%
def crop_image(img):
    new_img=img[70:-25,:,:]
    return new_img

# %%
def process_img(path):
    img=read_image(path)
    img=crop_image(img)
    img=resize_image(img)

# %%
def process(image):
    img = crop_image(image)
    img = resize_image(img)
    return img

# %%
def choose_image(path_row,steering):
    ch=np.random.choice(3)
    img=process_img(path_row[ch])
    steering_angle=float(steering)
    #for left
    if (ch == 1):
        steering_angle += 0.2
    #for right
    if (ch == 2):
        steering_angle -= 0.2
    
    return img, steering_angle    

def flip_image(img, angle):
    ch = np.random.choice(2)
    if ch == 0:
        return img, angle
    else:
        return cv2.flip(img,1), -angle

# %%
ds=pd.read_csv('C:/Users/Anuj_Chauhan/Desktop/driving_log.csv')
ds.head()
# Out:
#   C:\Users\Anuj_Chauhan\Desktop\IMG\center_2018_07_13_22_05_01_387.jpg  \
# 0  C:\Users\Anuj_Chauhan\Desktop\IMG\center_2018_...
# 1  C:\Users\Anuj_Chauhan\Desktop\IMG\center_2018_...
# 2  C:\Users\Anuj_Chauhan\Desktop\IMG\center_2018_...
# 3  C:\Users\Anuj_Chauhan\Desktop\IMG\center_2018_...
# 4  C:\Users\Anuj_Chauhan\Desktop\IMG\center_2018_...
#
#   C:\Users\Anuj_Chauhan\Desktop\IMG\left_2018_07_13_22_05_01_387.jpg  \
# 0  C:\Users\Anuj_Chauhan\Desktop\IMG\left_2018_07...
# 1  C:\Users\Anuj_Chauhan\Desktop\IMG\left_2018_07...
# 2  C:\Users\Anuj_Chauhan\Desktop\IMG\left_2018_07...
# 3  C:\Users\Anuj_Chauhan\Desktop\IMG\left_2018_07...
# 4  C:\Users\Anuj_Chauhan\Desktop\IMG\left_2018_07...
#
#   C:\Users\Anuj_Chauhan\Desktop\IMG\right_2018_07_13_22_05_01_387.jpg     0  \
# 0  C:\Users\Anuj_Chauhan\Desktop\IMG\right_2018_0...                   0.00
# 1  C:\Users\Anuj_Chauhan\Desktop\IMG\right_2018_0...                   0.00
# 2  C:\Users\Anuj_Chauhan\Desktop\IMG\right_2018_0...                   0.00
# 3  C:\Users\Anuj_Chauhan\Desktop\IMG\right_2018_0...                   0.00
# 4  C:\Users\Anuj_Chauhan\Desktop\IMG\right_2018_0...                  -0.05
#
#      1  0.1  30.19031
# 0  1.0    0  30.19031
# 1  1.0    0  30.19029
# 2  1.0    0  30.19029
# 3  1.0    0  30.19089
# 4  1.0    0  30.18751

# %%
ds.columns.tolist()
# Out:
# ['C:\\Users\\Anuj_Chauhan\\Desktop\\IMG\\center_2018_07_13_22_05_01_387.jpg',
#  'C:\\Users\\Anuj_Chauhan\\Desktop\\IMG\\left_2018_07_13_22_05_01_387.jpg',
#  'C:\\Users\\Anuj_Chauhan\\Desktop\\IMG\\right_2018_07_13_22_05_01_387.jpg',
#  '0',
#  '1',
#  '0.1',
#  '30.19031']

# %%
def generate_dataset():
    df=pd.read_csv('C:/Users/Anuj_Chauhan/Desktop/driving_log.csv')
    X=df[['C:\\Users\\Anuj_Chauhan\\Desktop\\IMG\\center_2018_07_13_22_05_01_387.jpg','C:\\Users\\Anuj_Chauhan\\Desktop\\IMG\\left_2018_07_13_22_05_01_387.jpg','C:\\Users\\Anuj_Chauhan\\Desktop\\IMG\\right_2018_07_13_22_05_01_387.jpg']].values
    Y = df['30.19031'].values
    
    data_X = np.empty( [X.shape[0], imgh, imgw,imgc],dtype='uint8' )
    data_Y = np.empty( [ Y.shape[0] ] )
    for i in range(X.shape[0]):

        img, angle = choose_image(X[i], Y[i])
        img, angle = flip_image(img, angle)

        data_X[i] = img
        data_Y[i] = angle
        
    return data_X, data_Y

# %%
a,b=generate_dataset()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-ce680f300575> in <module>()
# ----> 1 a,b=generate_dataset()
#
# <ipython-input-15-4aca657c031a> in generate_dataset()
#      11         img, angle = flip_image(img, angle)
#      12
# ---> 13         data_X[i] = img
#      14         data_Y[i] = angle
#      15
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
